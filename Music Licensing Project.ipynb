# %%
#using functions, modules & file handling
import time
import license as l

f_id=open('userid.txt','a+')
g_pw=open('pass.txt','a+')
flag=0

print("\t               Welcome to Music Licensing Database🎵🎼")
op=''

while(op.lower()!='n'):
    f_id.seek(0)
    g_pw.seek(0)
    print("\n\t\t\t     ⚡1.Log-in\n\t\t\t     ⚡2.Sign-up ")
    ch4=input("\n\t\t\tSelect from the above ")
    
    if(ch4=='1'):
        id1=input("\n\t\t Enter User Id to continue: ")
        pass1=input("\n\t\t Enter password ⚠ ")
        
        idd=f_id.readlines()
        paas=g_pw.readlines()
        
        for i in idd:                                       #id check
            for j in i.split(): 
                if(id1==j):
                    for k in paas:                          #password check
                        for l2 in k.split():
                            if(pass1==l2):
                                flag=1
                                print("\n\t\tSigning in... PLEASE HOLD YOUR HORSES🙏🏻")
                                time.sleep(1.5)
                                print("\n\t\t\tWELCOME AGAIN ",id1)#delay of 1.5 seconds
                                time.sleep(1.5)
                                l.menu()
                                break
                    break
        if(flag==0):
            print("\n\t\t\tWrong ID or Password")
        

    elif(ch4=='2'):
        l1=input("\n\t\t\t\tDo you want to create a new account? (Y/N) ")
        if(l1.lower()=='y'):
            id2=input("\t\t\tEnter User Id ")
            pass2=input("\t\t\tCreate a password ") 
            f_id.write(id2+'\n')
            g_pw.write(pass2+'\n')
            print("\n\t\t\t     Account Successfully Created!")
            
        else:
            print("\n\t\t\tTry Again") 
    else:
        print("\n\t\t\tYou've entered wrong choice!") 
        
        
    op=input("\n\t\t\t\tDo you want to \'LOG-IN\' again? (Y or N) ")
print("\n\t\t\t\t\t have a nice day:)")

f_id.close()
g_pw.close()

# %%
#using functions & modules
import time
import license as l


print("\t               Welcome to Music Licensing Database🎵🎼")
op=''
while(op.lower()!='n'):
    print("\n\t\t\t     ⚡1.Log-in\n\t\t\t     ⚡2.Sign-up ")
    ch4=input("\n\t\t\tSelect from the above ")
    
    if(ch4=='1'):
        id1=input("\n\t\t Enter User Id to continue: ")
        pass1=input("\n\t\t Enter password ⚠ ")
        
        if(id1=='new_music1' and pass1=='music@1database'): #checking password
            print("\n\t\tSigning in... PLEASE HOLD YOUR HORSES🙏🏻")
            time.sleep(1.5)
            print("\n\t\t\tWELCOME AGAIN ",id1)#delay of 1.5 seconds
            time.sleep(1.5)
            l.menu()
            break
        else:
            print("\n\t\t\t\tWrong ID or Password!")

    elif(ch4=='2'):
        l=input("\n\t\t\t\tDo you want to create a new account? (Y/N) ")
        if(l.lower()=='y'):
            id2=input("\t\t\tEnter User Id ")
            pass2=input("\t\t\tCreate a password ") 
            print("\n\t\t\t     Account Successfully Created!")
            
        else:
            print("\n\t\t\tTry Again") 
    else:
        print("\n\t\t\tYou've entered wrong choice!") 
        
        
    op=input("\n\t\t\t\tDo you want to \'LOG-IN\' again? (Y or N) ")
    print("\n\t\t\t\t\t have a nice day:)")

# %%
#import license as l (l is module)
#x=dir(l)

# %%
#import project (project is module)
#x=dir(project)

# %%
#using functions
import time
import random
a_music={}

def menu():
    d=''
    while(d.lower()!='n'): 
        print('''\n\n\t\t\tChoose from the below options~\n\t\t\tA. Add Music Data\n\t\t\tB. Display \'ALL\' Data\n\t\t\tC. Search for Music\n\t\t\tD. Sort by streams\n\t\t\tE. Remove Records\n\t\t\tF. Display top 5\n\t\t\tG. Update Records''')
        ch=input("\nWhich operation do you wanna perform? ")
        choice(ch)
        
        d=input("\n\t\tDo you want to continue(Y/N)? " )
    print("\n\t\t\t\tthank you for using our services:)")


    
def generate_isrc():
    l=[]
    s1=''
    r1=random.randint(0,25)
    r2=random.randint(0,25)
    r3=random.randint(0,25)
    r4=str(random.randint(10,99))
    r5=str(random.randint(0,9))

    for i in range(65,91):
        l.append(chr(i))
    
    s1+=l[r1]
    s1+=r4
    s1+='-'
    s1+=r5
    s1+=l[r2]
    s1+=l[r3]
    
    return s1
    
def add_data():
    ch=''
    while(ch.lower()!='n'):
        isrc=generate_isrc()
        s_name=input("\n\t\t Enter Song Name ")
        g_name=input("\n\t\t Enter Genre of the Song ")
        a_name=input("\n\t\t Enter Artist's Name ")
        y_rl=int(input("\n\t\t Enter Year of Release "))
        tempo=input("\n\t\t Enter Tempo of the Song ")
        streams=int(input("\n\t\t Enter number of streams "))
        a_music[isrc]=[s_name,g_name,a_name,y_rl,tempo,streams]
                
        ch=input("\n\t\t Do you want to add more songs (Y/N)? ")
    print("\t\t\tAdding Now! Please wait:)")
    time.sleep(1.5)
    for i in a_music:
        print("\n\t\t\t ISRC of the Song is- ", i,sep='\n')
        
        
def view_data():
    if(a_music!={}):
        print("\nISRC\t\tSong\t\tGenre\t\tArtist\t\tYoR\t\tTempo\t\tStreams")
        for i in a_music:
            print("\n",i,end='\t\t')
            for j in a_music[i]:
                print(j,end='\t\t')
    else: 
        print("\n\t\t\tNo Data to Display!")


        
def search():
    flag=0
    print("\n\t\t\tSearch on the basis of:\n\t\t\t\t 1. ISRC\n2. Song Name\n3. Artist\n4. Year of Release\n5. Tempo\n6. Genre")
    ch1=int(input("\n\t\t\t\tEnter from the above options "))
    if(ch1==1):
        is_rc=input("\n\t\t\tPut in the ISRC, which you want to search ")
        for i in a_music:
            if(is_rc==i):
                print("\n\t\tISRC\tSong Name\tArtist")
                print(i,a_music[i][0],a_music[i][2],sep='\t')
                flag=1
            
        if(flag==0):
            print("\n\t\t\tISRC doesn't match our records:/")
                
                
    elif(ch1==2):
        song=input("\n\t\t\tPut in the song name ")
        for i in a_music:
                if(song==a_music[i][0]):
                    print("\n\t\tSong Name\tISRC\tArtist")
                    print(a_music[i][0],i,a_music[i][2],sep='\t')
                    flag=1
            
        if(flag==0):
            print("\n\t\t\tSong Name doesn't match our records:/")
    
    elif(ch1==3):
        artist=input("\n\t\t\tPut in the artist's name ")
        for i in a_music:
            if(a_music[i][2]==artist):
                print("\n\t\tArtist\tISRC\tSong Name")
                print(a_music[i][2],i,a_music[i][0],sep='\t')
                flag=1
                
        if(flag==0):
            print("\n\t\t\tArtist doesn't match our records:/")
    
    elif(ch1==4):
        y_o_r=int(input("\n\t\t\tPut in the year of release "))
        for i in a_music:
            if(a_music[i][3]==y_o_r):
                print("\n\t\tYoR\tISRC\tSong Name")
                print(a_music[i][3],i,a_music[i][0],sep='\t')
                flag=1
                
        if(flag==0):
            print("\n\t\t\tYoR doesn't match our records:/")
        
    elif(ch1==5):
        tempo=input("\n\t\t\tEnter tempo ")
        for i in a_music:
            if(a_music[i][4]==tempo):
                print("\n\t\tTempo\tISRC\tSong Name")
                print(a_music[i][4],i,a_music[i][0],sep='\t')  
                flag=1
                
        if(flag==0):
                print("\n\t\t\tTempo doesn't match our records:/")
        
    elif(ch1==6):
        genre=input("\n\t\t\tEnter genre ")
        for i in a_music:
            if(a_music[i][1]==genre):
                print("\n\t\tGenre\tISRC\tSong Name")
                print(a_music[i][1],i,a_music[i][0],sep='\t') 
                flag=1
                
        if(flag==0):
            print("\n\t\t\tGenre doesn't match our records:/")
            
            
def update_all(isrc):
        s_name=input("\n\t\t Enter Song Name ")
        g_name=input("\n\t\t Enter Genre of the Song ")
        a_name=input("\n\t\t Enter Artist's Name ")
        y_rl=int(input("\n\t\t Enter Year of Release "))
        tempo=input("\n\t\t Enter Tempo of the Song ")
        streams=int(input("\n\t\t Enter number of streams "))
        a_music[isrc]=[s_name,g_name,a_name,y_rl,tempo,streams]
        
        print("\n\t\t\t Updating ALL records now!!")
    
    
                
def update_records():
    flag=0
    is_rc=input("\n\t\t\tPut in the ISRC, for which you want to update records ")
    for i in a_music:
        if(is_rc==i):
            flag=1
            print("\n\t\tUpdation starting NOW")
            time.sleep(1.5)
            ch=input("\n\t\tDo you want to update all the records (Y/N) ")
            
            if(ch.lower()=='y'):
                update_all(is_rc)
                
            else:    
                print("\n\t\t\tWhat do you want to update:\n\t1. Song Name\n2. Artist\n3. Year of Release\n4. Tempo\n5. Genre\n6. Streams")
                ch2=int(input("\n\t\t\t\tEnter from the above options "))
            
                if(ch2==1):
                    s_name=input("\t\t\tEnter New Song Name ")
                    a_music[i][0]=s_name
            
                elif(ch2==2):
                    artist=input("\t\t\tEnter New Artist Name ")
                    a_music[i][2]=artist
                
                elif(ch2==3):
                    y_o_r=int(input("\t\t\tEnter New Year of Release "))
                    a_music[i][3]=y_o_r
            
                elif(ch2==4):
                    tempo=input("\t\t\tEnter New Tempo ")
                    a_music[i][4]=tempo
            
                elif(ch2==5):
                    g_name=input("\t\t\tEnter New Genre ")
                    a_music[i][2]=g_name
                
                elif(ch2==6):
                    streams=int(input("\t\t\tEnter New Number of Streams "))
                    a_music[i][5]=streams
            
                else:
                    print("\n\t\tYou've entered wrong choice ")   
                    
         
    if(flag==0):
            print("\n\t\t\tISRC doesn't match our records:/")

def remove_records():
    flag=0
    ch=input("\n\t\tEnter ISRC of the record which you wanna delete ")
    for i in a_music:
        if(i==ch):
            flag=1
            a_music.pop(i)
    if(flag==0):
        print("\n\t\tIncorrect ISRC entered")
    print("\n\n\t\tSuccessfully Removed")
    
    
def choice(ch3):
    if(ch3.lower()=='a'):
        add_data()
    elif(ch3.lower()=='b'):
        view_data()
    elif(ch3.lower()=='c'):
        search()
    elif(ch3.lower()=='e'):
        remove_records()
    elif(ch3.lower()=='g'):
        update_records()
    else:
        print("\n\t\t\t\t\tsorry! wrong choice entered")
    #elif(ch.lower()='c'):

    
            
print("\t               Welcome to Music Licensing Database🎵🎼")
op=''
while(op.lower()!='n'):
    print("\n\t\t\t     ⚡1.Log-in\n\t\t\t     ⚡2.Sign-up ")
    ch4=input("\n\t\t\tSelect from the above ")
    
    if(ch4=='1'):
        id1=input("\n\t\t Enter User Id to continue: ")
        pass1=input("\n\t\t Enter password ⚠ ")
        
        if(id1=='new_music1' and pass1=='music@1database'): #checking password
            print("\n\t\tSigning in... PLEASE HOLD YOUR HORSES🙏🏻")
            time.sleep(1.5)
            print("\n\t\t\tWELCOME AGAIN ",id1)#delay of 1.5 seconds
            time.sleep(1.5)
            menu()
            break
        else:
            print("\n\t\t\t\tWrong ID or Password!")

    elif(ch4=='2'):
        l=input("\n\t\t\t\tDo you want to create a new account? (Y/N) ")
        if(l.lower()=='y'):
            id2=input("\t\t\tEnter User Id ")
            pass2=input("\t\t\tCreate a password ") 
            print("\n\t\t\t     Account Successfully Created!")
            
        else:
            print("\n\t\t\tTry Again") 
    else:
        print("\n\t\t\tYou've entered wrong choice!") 
        
        
    op=input("\n\t\t\t\tDo you want to \'LOG-IN\' again? (Y or N) ")
    print("\n\t\t\t\t\t have a nice day:)")

# %%
#basic start
import time
a_music={}
c=''
op=''
ch=''


def main_menu():
    d=''
    while(d.lower()!='n'): 
        print('''\n\nChoose from the below options~\nA. Add Music Data\nB. Display \'ALL\' Data\nC. Search for Music\nD. Sort by streams\nE. Remove Records\nF. Display top 5\nG. Update Records''')
                
        ch1=input("\nWhich operation do you wanna perform? ")
        if(ch1.lower()=='a'):
            n=int(input("How many song details you want to enter? "))
            for i in range(n):
                isrc=input("Enter ISRC of the song ")
                s_name=input("Enter Song Name ")
                g_name=input("Enter Genre of the Song ")
                a_name=input("Enter Artist's Name ")
                y_rl=input("Enter Year of Release ")
                tempo=input("Enter Tempo of the Song ")
                streams=int(input("Enter number of streams "))
                a_music[isrc]=[s_name,g_name,a_name,y_rl,tempo,streams]
                
                print("\t\t\t\t\t\tAdding Now! Please wait:)")
                time.sleep(1.5)
                
        elif(ch1.lower()=='b'):
            if(a_music!={}):
                print("\nISRC\t\tSong\t\tGenre\t\tArtist\t\tYoR\t\tTempo\t\tStreams")
                for i in a_music:
                    print("\n",i,end='\t\t')
                    for j in a_music[i]:
                        print(j,end='\t\t')
            else: 
                print("\nNo Data to Display!")
                
        else:
            print("wrong choice!")

    
        d=input("\nDo you want to continue(Y/N)? " )
    print("\n\t\t\t\tthank you for using our services:)")
    

print("\t\t\t\tWelcome to Music Licensing Database🎵🎼")
while(op.lower()!='n'):
    print("\n⚡1.Log-in\n⚡2.Sign-up ")
    ch=input("\nSelect from the above ")
    
    if(ch=='1'):
        id1=input("\nEnter User Id to continue ")
        pass1=input("\nEnter password ⚠")
        
        if(id1=='new_music1' and pass1=='music@1database'): #checking password
            print("\n\t\t\t\tSigning in... PLEASE HOLD YOUR HORSES🙏🏻")
            time.sleep(1.5) #delay of 1.5 seconds
            main_menu()
            break;
        else:
            print("Wrong ID or Password!")
        
        
    elif(ch=='2'):
        l=input("Do you want to create a new account? (Y/N) ")
        if(l.lower()=='y'):
            id2=input("Enter User Id ")
            pass2=input("Create a password ") 
            print("\n\t\t\t     Account Successfully Created!")
            
        else:
            print("Try Again") 
    else:
        print("You've entered wrong choice!")

    op=input("\nDo you want to try again? (Y or N) ")
    print("\n\t\t\t\t\t have a nice day:)")
